# %% [markdown]
# # Commandes de lancement de Scrapy

# %%
import scrapy

# %% [markdown]
# Cette commande permet de créer le projet Scrapy imdbcrawler :

# %%
# !scrapy startproject imdbcrawler
# Out:
# New Scrapy project 'imdbcrawler', using template directory 'c:\users\cel pro\anaconda3\lib\site-packages\scrapy\templates\project', created in:
#     C:\Users\Cel pro\Documents\E4\DSIA-4201C\DataEngineerTools\6Evaluation\pro\imdbcrawler
#
# You can start your first spider with:
#     cd imdbcrawler
#     scrapy genspider example example.com

# %% [markdown]
# Cette commande permet de créer la Spider imdb pour scraper le domaine www.imdb.com :

# %%
# !cd imdbcrawler && scrapy genspider imdb www.imdb.com
# Out:
# Created spider 'imdb' using template 'basic' in module:
#   imdbcrawler.spiders.imdb

# %% [markdown]
# Pour lancer la spider imdb (exporté par -o imdb.json) :

# %%
# !cd imdbcrawler && scrapy crawl imdb -o ../myApp/imdb.json
# Out:
# 2021-02-07 21:28:47 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: imdbcrawler)
# 2021-02-07 21:28:47 [scrapy.utils.log] INFO: Versions: lxml 4.6.1.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.8.6 (default, Oct 13 2020, 20:37:26) - [GCC 8.3.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1h  22 Sep 2020), cryptography 3.2.1, Platform Linux-4.19.128-microsoft-standard-x86_64-with-glibc2.2.5
# 2021-02-07 21:28:47 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2021-02-07 21:28:47 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'imdbcrawler',
#  'NEWSPIDER_MODULE': 'imdbcrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['imdbcrawler.spiders']}
# 2021-02-07 21:28:47 [scrapy.extensions.telnet] INFO: Telnet Password: 7f4f10e1e0b5e59b
# 2021-02-07 21:28:47 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
# ...
